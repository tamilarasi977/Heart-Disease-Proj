# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
heart_sets = pd.read_csv("heart.csv")

# %%
#print first 5 rows of the dataset
heart_sets.head()
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  52.0    1   0       125   212    0        1      168      0      1.0
# 1  53.0    1   0       140   203    1        0      155      1      3.1
# 2   NaN    1   0       145   174    0        1      125      1      2.6
# 3  61.0    1   0       148   203    0        1      161      0      0.0
# 4  62.0    0   0       138   294    1        1      106      0      1.9
#
#    slope  ca  thal  target
# 0      2   2     3       0
# 1      0   0     3       0
# 2      0   0     3       0
# 3      2   1     3       0
# 4      1   3     2       0

# %%
#print Last 5 rows of the dataset
heart_sets.tail()
# Out:
#        age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020  59.0    1   1       140   221    0        1      164      1      0.0
# 1021  60.0    1   0       125   258    0        0      141      1      2.8
# 1022  47.0    1   0       110   275    0        0      118      1      1.0
# 1023  50.0    0   0       110   254    0        0      159      0      0.0
# 1024  54.0    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
# number of rows and columns in the dataset
heart_sets.shape
# Out:
# (1025, 14)

# %%
# getting information about the marks data
heart_sets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1024 non-null   float64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(2), int64(12)
# memory usage: 112.2 KB

# %%
# find the missing values from data sets
heart_sets.isnull().sum()
# Out:
# age         1
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# statistical measures about the data
heart_sets.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1024.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.418945     0.695610     0.942439   131.611707   246.00000
# std       9.063654     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
# correlation and plotting:
correlation=heart_sets.corr()
correlation
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.104522 -0.070562  0.270306  0.222696  0.122132
# sex      -0.104522  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.070562 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.270306 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.222696 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.122132  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.134436 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.389238 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.086016  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.206423  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.165991 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.273242  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.070613  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
# checking the distribution of Target Variable
heart_sets['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
heart_sets.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

heart_sets.plot()

plt.show()
